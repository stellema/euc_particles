# %%
import sys
import numpy as np
import xarray as xr

# %%
path = '/g/data/rr7/JRA55/6hr/atmos/'
u, v = [], []
y = 1982

# %%
var = 'huss'
ds = xr.open_dataset(path + '{}/v1/{}_6hrPlev_JRA55_{}010100_{}123118.nc'.format(var, var, y, y))
ds[var]
# Out:
# <xarray.DataArray 'huss' (time: 1460, lat: 145, lon: 288)>
# [60969600 values with dtype=float32]
# Coordinates:
#   * lon      (lon) float32 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.25 357.5 358.75
#   * lat      (lat) float32 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#   * time     (time) datetime64[ns] 1982-01-01 ... 1982-12-31T18:00:00
# Attributes:
#     standard_name:  specific_humidity
#     long_name:      Near-Surface Specific Humidity
#     units:          1
#     title:          ** 2 m above ground Specific humidity [kg/kg]

# %%
var = 'tas'
ds = xr.open_dataset(path + '{}/v1/{}_6hrPlev_JRA55_{}010100_{}123118.nc'.format(var, var, y, y))
ds[var]
# Out:
# <xarray.DataArray 'tas' (time: 1460, lat: 145, lon: 288)>
# [60969600 values with dtype=float32]
# Coordinates:
#   * lon      (lon) float32 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.25 357.5 358.75
#   * lat      (lat) float32 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#   * time     (time) datetime64[ns] 1982-01-01 ... 1982-12-31T18:00:00
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Surface (2m) air temperature
#     units:          K
#     title:          ** 2 m above ground Temperature [K]

# %%
var = 'psl'
ds = xr.open_dataset(path + '{}/v1/{}_6hrPlev_JRA55_{}010100_{}123118.nc'.format(var, var, y, y))
ds[var]
# Out:
# <xarray.DataArray 'psl' (time: 1460, lat: 145, lon: 288)>
# [60969600 values with dtype=float32]
# Coordinates:
#   * lon      (lon) float32 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.25 357.5 358.75
#   * lat      (lat) float32 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#   * time     (time) datetime64[ns] 1982-01-01 ... 1982-12-31T18:00:00
# Attributes:
#     standard_name:  air_pressure_at_sea_level
#     long_name:      Sea Level Pressure
#     units:          Pa
#     title:          ** mean-sea level Pressure reduced to MSL [Pa]

# %%
var = 'vas'
ds = xr.open_dataset(path + '{}/v1/{}_6hrPlev_JRA55_{}010100_{}123118.nc'.format(var, var, y, y))
ds[var]
# Out:
# <xarray.DataArray 'vas' (time: 1460, lat: 145, lon: 288)>
# [60969600 values with dtype=float32]
# Coordinates:
#   * lon      (lon) float32 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.25 357.5 358.75
#   * lat      (lat) float32 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#   * time     (time) datetime64[ns] 1982-01-01 ... 1982-12-31T18:00:00
# Attributes:
#     standard_name:  northward_wind
#     long_name:      Northward near-surface wind
#     units:          m s-1
#     title:          ** 10 m above ground v-component of wind [m/s]

# %%
var = 'ta'
ds = xr.open_dataset(path + 'reg-tl319/{}/v1/{}_6hrLev_JRA55_reg-tl319_{}010100-{}013118.nc'.format(var, var, y, y))
var2 = 'tas'
dss = xr.open_dataset(path + '{}/v1/{}_6hrPlev_JRA55_{}010100_{}123118.nc'.format(var2, var2, y, y))

# %%
print(dss[var2].sel(lat=2, lon=0, method='nearest')[0])
print(ds[var].sel(lat=2.5, lon=0, method='nearest')[0, 3])
# Out:
# <xarray.DataArray 'tas' ()>
# array(300.169586)
# Coordinates:
#     lon      float32 0.0
#     lat      float32 2.5
#     time     datetime64[ns] 1982-01-01
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Surface (2m) air temperature
#     units:          K
#     title:          ** 2 m above ground Temperature [K]
# <xarray.DataArray 'ta' ()>
# array(297.62323)
# Coordinates:
#     time      datetime64[ns] 1982-01-01
#     hybl_lev  float32 4.0
#     lat       float32 2.527
#     lon       float32 0.0
# Attributes:
#     title:          ** (profile) Temp. [K]
#     long_name:      Air Temperature
#     standard_name:  air_temperature
#     units:          K

# %%
c = [any(ds.lat == np.round(x,2)) for x in dss.lat]

# %%
dss
# Out:
# <xarray.Dataset>
# Dimensions:   (bnds: 2, lat: 145, lon: 288, time: 1460)
# Coordinates:
#   * lon       (lon) float32 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.25 357.5 358.75
#   * lat       (lat) float32 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#   * time      (time) datetime64[ns] 1982-01-01 ... 1982-12-31T18:00:00
# Dimensions without coordinates: bnds
# Data variables:
#     lon_bnds  (lon, bnds) float32 ...
#     lat_bnds  (lat, bnds) float32 ...
#     tas       (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.7.1 (http://mpimet.mpg.de/...
#     history:      Wed Aug 03 13:45:07 2016: cdo mergetime tas_A6hr_JRA55_1982...
#     Conventions:  CF-1.0
#     reference:    Kobayashi, S., Y. Ota, Y. Harada, A. Ebita, M. Moriya, H. O...
#     CDO:          Climate Data Operators version 1.7.1 (http://mpimet.mpg.de/...
